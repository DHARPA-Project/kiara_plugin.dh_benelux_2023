# %% [markdown]
# ## 0. Installation

# %%
try:
    from kiara_plugin.jupyter import ensure_kiara_plugins
except:
    import sys
    print("Installing 'kiara_plugin.jupyter'...")
    # !{sys.executable} -m pip install -q kiara_plugin.jupyter
    from kiara_plugin.jupyter import ensure_kiara_plugins

import sys
# !{sys.executable} -m pip install kiara_plugin.language_processing==0.4.13

ensure_kiara_plugins()

from kiara.api import KiaraAPI
kiara = KiaraAPI.instance()
# Out:
# Installing 'kiara_plugin.jupyter'...
# Requirement already satisfied: kiara_plugin.language_processing==0.4.13 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (0.4.13)
# Requirement already satisfied: gensim>=4.2.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara_plugin.language_processing==0.4.13) (4.3.1)
# Requirement already satisfied: kiara-plugin.tabular>=0.4.22 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara_plugin.language_processing==0.4.13) (0.4.22)
# Requirement already satisfied: nltk>=3.7 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara_plugin.language_processing==0.4.13) (3.8.1)
# Requirement already satisfied: scipy>=1.7.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from gensim>=4.2.0->kiara_plugin.language_processing==0.4.13) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from gensim>=4.2.0->kiara_plugin.language_processing==0.4.13) (6.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from gensim>=4.2.0->kiara_plugin.language_processing==0.4.13) (1.24.2)
# Requirement already satisfied: kiara-plugin.core-types>=0.4.16 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.4.16)
# Requirement already satisfied: kiara>=0.4.32 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.4.34)
# Requirement already satisfied: sqlalchemy-utc>=0.10.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.10.0)
# Requirement already satisfied: polars>=0.15.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.16.17)
# Requirement already satisfied: sqlalchemy-utils>=0.38.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.40.0)
# Requirement already satisfied: pandas>=1.4.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.0.0)
# Requirement already satisfied: pyarrow>=9.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (11.0.0)
# Requirement already satisfied: sqlite-utils==3.30 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.30)
# Collecting duckdb<0.7.0,>=0.6.0
#   Using cached duckdb-0.6.1-cp39-cp39-macosx_10_9_x86_64.whl (13.6 MB)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.0.8)
# Requirement already satisfied: click in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (8.1.3)
# Requirement already satisfied: sqlite-fts4 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.0.3)
# Requirement already satisfied: python-dateutil in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.8.2)
# Requirement already satisfied: tabulate in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.9.0)
# Requirement already satisfied: click-default-group-wheel in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.2.2)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from nltk>=3.7->kiara_plugin.language_processing==0.4.13) (4.65.0)
# Requirement already satisfied: joblib in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from nltk>=3.7->kiara_plugin.language_processing==0.4.13) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from nltk>=3.7->kiara_plugin.language_processing==0.4.13) (2023.3.23)
# Requirement already satisfied: networkx<4.0,>=3.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.1)
# Requirement already satisfied: pyzmq>=25.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (25.0.2)
# Requirement already satisfied: dag-cbor<0.4.0,>=0.3.2 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.3.2)
# Requirement already satisfied: humanfriendly>=10.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (10.0)
# Requirement already satisfied: importlib-metadata<7.0.0,>=3.0.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (4.13.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.4.0)
# Requirement already satisfied: tzlocal<5.0,>=2.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (4.3)
# Requirement already satisfied: pytz>=2022.6 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2023.3)
# Requirement already satisfied: alembic>=1.7.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.10.2)
# Requirement already satisfied: multiformats-config<0.3.0,>=0.2.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.2.0.post4)
# Requirement already satisfied: rich>=12.4.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (13.3.3)
# Requirement already satisfied: dpath>=2.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.1.5)
# Requirement already satisfied: boltons>=21.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (23.0.0)
# Requirement already satisfied: fasteners>=0.18 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.18)
# Requirement already satisfied: rich-click>=1.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.6.1)
# Requirement already satisfied: httpx>=0.23.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.23.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.4.4)
# Requirement already satisfied: distro>=1.6.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.8.0)
# Requirement already satisfied: orjson>=3.6.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.8.8)
# Requirement already satisfied: mmhash3>=3.0.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.0.1)
# Requirement already satisfied: structlog>=21.5.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (22.1.0)
# Requirement already satisfied: pydantic[email]>=1.10.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.10.7)
# Requirement already satisfied: jinja2>=3.0.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.1.2)
# Requirement already satisfied: pp-ez>=0.2.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.2.0)
# Requirement already satisfied: bidict>=0.21.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.22.1)
# Requirement already satisfied: deepdiff<7.0.0,>=6.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (6.3.0)
# Requirement already satisfied: multiformats<0.3.0,>=0.2.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.0.5)
# Requirement already satisfied: textual<0.11.0,>=0.9.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.10.1)
# Requirement already satisfied: filetype<2.0.0,>=1.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.2.0)
# Requirement already satisfied: docstring-parser>=0.15.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.15)
# Requirement already satisfied: ruamel.yaml<0.18.0,>=0.17.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.17.21)
# Requirement already satisfied: stevedore<6.0.0,>=5.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (5.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from pandas>=1.4.0->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2023.3)
# Requirement already satisfied: typing_extensions>=4.0.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from polars>=0.15.0->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlalchemy>=2.0.0->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.0.2)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from sqlalchemy-utc>=0.10.0->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (65.6.3)
# Requirement already satisfied: Mako in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from alembic>=1.7.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.2.4)
# Requirement already satisfied: typing-validation in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from dag-cbor<0.4.0,>=0.3.2->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.0.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from deepdiff<7.0.0,>=6.0.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (4.1.0)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from httpx>=0.23.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2022.12.7)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from httpx>=0.23.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.5.0)
# Requirement already satisfied: sniffio in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from httpx>=0.23.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from httpx>=0.23.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.16.3)
# Requirement already satisfied: zipp>=0.5 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from importlib-metadata<7.0.0,>=3.0.0.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from jinja2>=3.0.1->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.1.2)
# Requirement already satisfied: bases in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from multiformats<0.3.0,>=0.2.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.0.0)
# Requirement already satisfied: email-validator>=1.0.3 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from pydantic[email]>=1.10.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from python-dateutil->sqlite-utils==3.30->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from rich>=12.4.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from rich>=12.4.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.14.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from ruamel.yaml<0.18.0,>=0.17.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.2.7)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from stevedore<6.0.0,>=5.0.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (5.11.1)
# Requirement already satisfied: nanoid>=2.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from textual<0.11.0,>=0.9.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.0.0)
# Requirement already satisfied: pytz-deprecation-shim in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from tzlocal<5.0,>=2.1->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.1.0.post0)
# Requirement already satisfied: idna>=2.0.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from email-validator>=1.0.3->pydantic[email]>=1.10.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.4)
# Requirement already satisfied: dnspython>=1.15.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from email-validator>=1.0.3->pydantic[email]>=1.10.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (2.3.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.23.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (3.6.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.23.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/envs/dh_benelux_2023/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.4.0->kiara>=0.4.32->kiara-plugin.tabular>=0.4.22->kiara_plugin.language_processing==0.4.13) (0.1.2)
# Installing collected packages: duckdb
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 0.7.1
#     Uninstalling duckdb-0.7.1:
#       Successfully uninstalled duckdb-0.7.1
# Successfully installed duckdb-0.6.1
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## 1. Data onboarding

# %% [markdown]
# ### 1.1. Download text file bundle into dataframe

# %%
inputs = {
    "url": "https://github.com/DHARPA-Project/kiara.examples/archive/refs/heads/main.zip",
    "sub_path": "kiara.examples-main/examples/data/text_corpus/data"
 }

outputs = kiara.run_job('download.file_bundle', inputs=inputs)
outputs
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field               value                                                                                                              │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   download_metadata                                                                                                                      │
# │                         dict data     {                                                                                                  │
# │                                         "response_headers": [                                                                            │
# │                                           {                                                                                              │
# │                                             "access-control-allow-origin": "https://render.githubusercontent.com",                       │
# │                                             "content-disposition": "attachment; filename=kiara.examples-main.zip",                       │
# │                                             "content-security-policy": "default-src 'none'; style-src 'unsafe-inline'; sandbox",         │
# │                                             "content-type": "application/zip",                                                           │
# │                                             "etag": "W/\"9d8f49cfce48a6f6c36564fe61eacc7f2500fc6172a9eee2b0af99b608129a29\"",            │
# │                                             "strict-transport-security": "max-age=31536000",                                             │
# │                                             "vary": "Authorization,Accept-Encoding,Origin",                                              │
# │                                             "x-content-type-options": "nosniff",                                                         │
# │                                             "x-frame-options": "deny",                                                                   │
# │                                             "x-xss-protection": "1; mode=block",                                                         │
# │                                             "date": "Wed, 26 Apr 2023 13:02:05 GMT",                                                     │
# │                                             "transfer-encoding": "chunked",                                                              │
# │                                             "x-github-request-id": "6F78:FCDF:816CA5:989DCF:644920CD"                                    │
# │                                           },                                                                                             │
# │                                           {                                                                                              │
# │                                             "server": "GitHub.com",                                                                      │
# │                                             "date": "Wed, 26 Apr 2023 13:02:05 GMT",                                                     │
# │                                             "content-type": "text/html; charset=utf-8",                                                  │
# │                                             "vary": "X-PJAX, X-PJAX-Container, Turbo-Visit, Turbo-Frame, Accept-Encoding, Accept, X…     │
# │                                             "location": "https://codeload.github.com/DHARPA-Project/kiara.examples/zip/refs/heads/m…     │
# │                                             "cache-control": "max-age=0, private",                                                       │
# │                                             "strict-transport-security": "max-age=31536000; includeSubdomains; preload",                 │
# │                                             "x-frame-options": "deny",                                                                   │
# │                                             "x-content-type-options": "nosniff",                                                         │
# │                                             "x-xss-protection": "0",                                                                     │
# │                                             "referrer-policy": "no-referrer-when-downgrade",                                             │
# │                                             "content-security-policy": "default-src 'none'; base-uri 'self'; block-all-mixed-conten…     │
# │                                             "content-length": "0",                                                                       │
# │                                             "x-github-request-id": "4AD2:F3B6:4B2F912:4C533C7:644920CC"                                  │
# │                                           }                                                                                              │
# │                                         ],                                                                                               │
# │                                         "request_time": "2023-04-26T13:02:05.818300+00:00"                                               │
# │                                       }                                                                                                  │
# │                         dict schema   {                                                                                                  │
# │                                         "title": "dict",                                                                                 │
# │                                         "type": "object"                                                                                 │
# │                                       }                                                                                                  │
# │                                                                                                                                          │
# │   file_bundle                                                                                                                            │
# │                         bundle name       data                                                                                           │
# │                         number_of_files   16                                                                                             │
# │                         size              298452                                                                                         │
# │                         included files                                                                                                   │
# │                                             (relative) path                                        size                                  │
# │                                            ──────────────────────────────────────────────────────────────                                │
# │                                             La_Rassegna/sn84037025_1917-04-14_ed-1_seq-1_ocr.txt   20647                                 │
# │                                             La_Rassegna/sn84037025_1917-04-07_ed-1_seq-1_ocr.txt   19397                                 │
# │                                             La_Rassegna/sn84037025_1917-04-14_ed-2_seq-1_ocr.txt   20650                                 │
# │                                             La_Rassegna/sn84037025_1917-04-21_ed-1_seq-1_ocr.txt   21017                                 │
# │                                             La_Rassegna/sn84037025_1917-04-21_ed-2_seq-1_ocr.txt   20982                                 │
# │                                             La_Ragione/sn84037024_1917-05-05_ed-2_seq-1_ocr.txt    18474                                 │
# │                                             La_Ragione/sn84037024_1917-05-16_ed-1_seq-1_ocr.txt    18620                                 │
# │                                             La_Ragione/sn84037024_1917-05-16_ed-2_seq-1_ocr.txt    18698                                 │
# │                                             La_Ragione/sn84037024_1917-05-05_ed-1_seq-1_ocr.txt    18346                                 │
# │                                             La_Ragione/sn84037024_1917-04-25_ed-4_seq-1_ocr.txt    16235                                 │
# │                                             La_Ragione/sn84037024_1917-04-25_ed-3_seq-1_ocr.txt    16793                                 │
# │                                             La_Ragione/sn84037024_1917-04-25_ed-2_seq-1_ocr.txt    16679                                 │
# │                                             La_Ragione/sn84037024_1917-04-25_ed-1_seq-1_ocr.txt    16613                                 │
# │                                             La_Ragione/sn84037024_1917-05-16_ed-3_seq-1_ocr.txt    18540                                 │
# │                                             La_Ragione/sn84037024_1917-05-05_ed-4_seq-1_ocr.txt    18481                                 │
# │                                             La_Ragione/sn84037024_1917-05-05_ed-3_seq-1_ocr.txt    18280                                 │
# │                                                                                                                                          │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
file_bundle = outputs['file_bundle']

# %%
kiara.retrieve_operation_info('create.table.from.file_bundle')
# Out:
#
#  Author(s)
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         tabular
#                      Labels       package: kiara_plugin.tabular
#                      References   source_repo: ]8;id=526520;https://github.com/DHARPA-Project/kiara_plugin.tabular\https://github.com/DHARPA-Project/kiara_plugin.tabular]8;;\
#                                   documentation: ]8;id=615595;https://DHARPA-Project.github.io/kiara_plugin.tabular/\https://DHARPA-Project.github.io/kiara_plugin.tabular/]8;;\
#
#  Operation details
#                      Documentation   Create a table value from a text file_bundle.
#
#                                      The resulting table will have (at a minimum) the following collumns:
#                                      - id: an auto-assigned index
#                                      - rel_path: the relative path of the file (from the provided base path)
#                                      - content: the text file content
#
#                      Inputs
#                                        field name    type          description                              Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        file_bundle   file_bundle   The source value (of type                yes        -- no default --
#                                                                    'file_bundle').
#
#
#                      Outputs
#                                        field name   type    description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        table        table   The result value (of type 'table').

# %%
inputs = {
    'file_bundle' : file_bundle
}

outputs = kiara.run_job('create.table.from.file_bundle', inputs=inputs)
outputs
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field   value                                                                                                                          │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   table                                                                                                                                  │
# │             id   rel_path                        mime_type    size    content                          file_name                         │
# │            ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │             0    La_Ragione/sn84037024_1917-04   text/plain   16613   LA RAGIONE                       sn84037024_1917-04-25_ed-1_se     │
# │             1    La_Ragione/sn84037024_1917-04   text/plain   16679   LA RAG ONE                       sn84037024_1917-04-25_ed-2_se     │
# │             2    La_Ragione/sn84037024_1917-04   text/plain   16793   LA RAGIONE                       sn84037024_1917-04-25_ed-3_se     │
# │             3    La_Ragione/sn84037024_1917-04   text/plain   16235   contro i vili, i camorristi, i   sn84037024_1917-04-25_ed-4_se     │
# │             4    La_Ragione/sn84037024_1917-05   text/plain   18346   contro i vili, i camorristi, i   sn84037024_1917-05-05_ed-1_se     │
# │             5    La_Ragione/sn84037024_1917-05   text/plain   18474   LA RAGIONA                       sn84037024_1917-05-05_ed-2_se     │
# │             6    La_Ragione/sn84037024_1917-05   text/plain   18280   LA RAGIONE                       sn84037024_1917-05-05_ed-3_se     │
# │             7    La_Ragione/sn84037024_1917-05   text/plain   18481   LA RAGIONE                       sn84037024_1917-05-05_ed-4_se     │
# │             8    La_Ragione/sn84037024_1917-05   text/plain   18620   contro i vili, i camorristi, i   sn84037024_1917-05-16_ed-1_se     │
# │             9    La_Ragione/sn84037024_1917-05   text/plain   18698   LA RAG ONE                       sn84037024_1917-05-16_ed-2_se     │
# │             10   La_Ragione/sn84037024_1917-05   text/plain   18540   contro 1 vili, i camorristi, i   sn84037024_1917-05-16_ed-3_se     │
# │             11   La_Rassegna/sn84037025_1917-0   text/plain   19397   ■■■                              sn84037025_1917-04-07_ed-1_se     │
# │             12   La_Rassegna/sn84037025_1917-0   text/plain   20647   La Rassegna                      sn84037025_1917-04-14_ed-1_se     │
# │             13   La_Rassegna/sn84037025_1917-0   text/plain   20650   Both Phones                      sn84037025_1917-04-14_ed-2_se     │
# │             14   La_Rassegna/sn84037025_1917-0   text/plain   21017   ■ jSrìt** W?? iIK 38®f- i^M      sn84037025_1917-04-21_ed-1_se     │
# │             15   La_Rassegna/sn84037025_1917-0   text/plain   20982   ■Both Phones                     sn84037025_1917-04-21_ed-2_se     │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
inputs = {
    'table' : outputs['table'],
    'column_name' : 'content'
}

outputs = kiara.run_job('table.pick.column', inputs=inputs)
outputs
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field   value                                                                                                                          │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────                                      │
# │   array                                                                                                                                  │
# │             LA RAGIONE                                                                                                                   │
# │             LA RAG ONE                                                                                                                   │
# │             LA RAGIONE                                                                                                                   │
# │             contro i vili, i camorristi, i sicari, i falsari e gli austriacanti, nemici dell ...                                         │
# │             contro i vili, i camorristi, i sicari, i falsari e gli austriacanti, nemici dell ...                                         │
# │             LA RAGIONA                                                                                                                   │
# │             LA RAGIONE                                                                                                                   │
# │             LA RAGIONE                                                                                                                   │
# │             contro i vili, i camorristi, i sicari, i falsari e gli austriacanti, nemici dell ...                                         │
# │             LA RAG ONE                                                                                                                   │
# │             contro 1 vili, i camorristi, i sicari, i falsari e gli austriacanti, nemici dell ...                                         │
# │             ■■■                                                                                                                          │
# │             La Rassegna                                                                                                                  │
# │             Both Phones                                                                                                                  │
# │             ■ jSrìt** W?? iIK 38®f- i^M                                                                                                  │
# │             ■Both Phones                                                                                                                 │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
infos = metadata = kiara.retrieve_operations_info()
operations = {}
for op_id, info in infos.item_infos.items():
    if info.context.labels.get("package", None) == "kiara_plugin.language_processing":
        operations[op_id] = info

print(operations.keys())
# Out:
# dict_keys(['create.stopwords_list', 'generate.LDA.for.tokens_array', 'preprocess.tokens_array', 'tokenize.string', 'tokenize.texts_array'])

# %%
kiara.retrieve_operation_info('tokenize.texts_array')
# Out:
#
#  Author(s)
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         language_processing, tokenize, tokens
#                      Labels       package: kiara_plugin.language_processing
#                      References   source_repo: ]8;id=652145;https://github.com/DHARPA-Project/kiara_plugin.language_processing\https://github.com/DHARPA-Project/kiara_plugin.language_processing]8;;\
#                                   documentation: ]8;id=725567;https://DHARPA-Project.github.io/kiara_plugin.language_processing/\https://DHARPA-Project.github.io/kiara_plugin.language_processing/]8;;\
#
#  Operation details
#                      Documentation   Split sentences into words or words into characters.
#
#                                      In other words, this operation establishes the word boundaries (i.e., tokens) a very helpful way of
#                                      finding patterns. It is also the typical step prior to stemming and lemmatization
#
#                      Inputs
#                                        field name         type      description                             Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        texts_array        array     An array of text items to be            yes        -- no default --
#                                                                     tokenized.
#                                        tokenize_by_word   boolean   Whether to tokenize by word             no         True
#                                                                     (default), or character.
#
#
#                      Outputs
#                                        field name     type    description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        tokens_array   array   The tokenized content, as an array of lists of strings.

# %%
inputs = {
    'texts_array': outputs['array']
}

outputs = kiara.run_job('tokenize.texts_array', inputs=inputs)
outputs
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────                               │
# │   tokens_array                                                                                                                           │
# │                    ['LA', 'RAGIONE', 'ORGANO', 'DI', 'DIFESA', 'DELLA', "ITALIANITÀ'", 'contro', '1 ...                                  │
# │                    ['LA', 'RAG', 'ONE', 'contro', 'i', 'vili', ',', 'i', 'camorristi', ',', 'i', 's ...                                  │
# │                    ['LA', 'RAGIONE', 'ORGANO', 'DI', 'DIFESA', 'DELLA', 'ITALIANITÀ', 'contro', 'i' ...                                  │
# │                    ['contro', 'i', 'vili', ',', 'i', 'camorristi', ',', 'i', 'sicari', ',', 'i', 'f ...                                  │
# │                    ['contro', 'i', 'vili', ',', 'i', 'camorristi', ',', 'i', 'sicari', ',', 'i', 'f ...                                  │
# │                    ['LA', 'RAGIONA', 'ORGANO', 'DI', 'DIFESA', 'DELLA', 'ITALIANITÀ', 'contro', 'i' ...                                  │
# │                    ['LA', 'RAGIONE', 'ORGANO', 'DI', 'DIFESA', 'DELLA', "ITALIANITÀ'", 'contro', 'i ...                                  │
# │                    ['LA', 'RAGIONE', 'contro', 'i', 'vili', ',', '1', 'camorristi', ',', 'i', 'sica ...                                  │
# │                    ['contro', 'i', 'vili', ',', 'i', 'camorristi', ',', 'i', 'sicari', ',', 'i', 'f ...                                  │
# │                    ['LA', 'RAG', 'ONE', 'ORGANO', 'DI', 'DIFESA', 'DELLA', 'ITALIANITÀ', "''", 'con ...                                  │
# │                    ['contro', '1', 'vili', ',', 'i', 'camorristi', ',', 'i', 'sicari', ',', 'i', 'f ...                                  │
# │                    ['■■■', 'La', 'Rassegna', '_', 'I', 'Both', 'Phones', 'ANNO', 'L', 'No', '.', '1 ...                                  │
# │                    ['La', 'Rassegna', 'Jjoth', 'Phones', 'ANNO', 'L', 'No', '.', '2', 'BASTA', '!', ...                                  │
# │                    ['Both', 'Phones', 'ANNO', 'I', '.', 'No', '.', '2', 'BASTA', '!', '...', 'uà',  ...                                  │
# │                    ['■', 'jSrìt', '*', '*', 'W', '?', '?', 'iIK', '38®f-', 'i^M', 'F', '<', '5É', ' ...                                  │
# │                    ['■Both', 'Phones', 'ANNO', '11', '.', 'No', '.', '5', 'LE', 'COSE', 'A', 'POSTO ...                                  │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
kiara.retrieve_operation_info('preprocess.tokens_array')
# Out:
#
#  Author(s)
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         language_processing, tokens, preprocess
#                      Labels       package: kiara_plugin.language_processing
#                      References   source_repo: ]8;id=497028;https://github.com/DHARPA-Project/kiara_plugin.language_processing\https://github.com/DHARPA-Project/kiara_plugin.language_processing]8;;\
#                                   documentation: ]8;id=728927;https://DHARPA-Project.github.io/kiara_plugin.language_processing/\https://DHARPA-Project.github.io/kiara_plugin.language_processing/]8;;\
#
#  Operation details
#                      Documentation   Preprocess lists of tokens, incl. lowercasing, remove special characers, etc.
#
#                                      Lowercasing: Lowercase the words. This operation is a double-edged sword. It can be effective at
#                                      yielding potentially better results in the case of relatively small datasets or datatsets with a
#                                      high percentage of OCR mistakes. For instance, if lowercasing is not performed, the algorithm will
#                                      treat USA, Usa, usa, UsA, uSA, etc. as distinct tokens, even though they may all refer to the same
#                                      entity. On the other hand, if the dataset does not contain such OCR mistakes, then it may become
#                                      difficult to distinguish between homonyms and make interpreting the topics much harder.
#
#                                      Removing stopwords and words with less than three characters: Remove low information words. These
#                                      are typically words such as articles, pronouns, prepositions, conjunctions, etc. which are not
#                                      semantically salient. There are numerous stopword lists available for many, though not all,
#                                      languages which can be easily adapted to the individual researcher's needs. Removing words with less
#                                      than three characters may additionally remove many OCR mistakes. Both these operations have the dual
#                                      advantage of yielding more reliable results while reducing the size of the dataset, thus in turn
#                                      reducing the required processing power. This step can therefore hardly be considered optional in TM.
#
#                                      Noise removal: Remove elements such as punctuation marks, special characters, numbers, html
#                                      formatting, etc. This operation is again concerned with removing elements that may not be relevant
#                                      to the text analysis and in fact interfere with it. Depending on the dataset and research question,
#                                      this operation can become essential.
#
#                      Inputs
#                                        field name            type      description                          Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        tokens_array          array     The tokens array to pre-process.     yes        -- no default --
#                                        to_lowercase          boolean   Apply lowercasing to the text.       no         False
#                                        remove_alphanumeric   boolean   Remove all tokens that include       no         False
#                                                                        numbers (e.g. ex1ample).
#                                        remove_non_alpha      boolean   Remove all tokens that include       no         False
#                                                                        punctuation and numbers (e.g.
#                                                                        ex1a.mple).
#                                        remove_all_numeric    boolean   Remove all tokens that contain       no         False
#                                                                        numbers only (e.g. 876).
#                                        remove_short_tokens   integer   Remove tokens shorter or equal to    no         0
#                                                                        this value. If value is <= 0, no
#                                                                        filtering will be done.
#                                        remove_stopwords      list      Remove stopwords.                    no         -- no default --
#
#
#                      Outputs
#                                        field name     type    description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        tokens_array   array   The pre-processed content, as an array of lists of strings.

# %%
kiara.retrieve_operation_info('create.stopwords_list')
# Out:
#
#  Author(s)
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         language_processing
#                      Labels       package: kiara_plugin.language_processing
#                      References   source_repo: ]8;id=17519;https://github.com/DHARPA-Project/kiara_plugin.language_processing\https://github.com/DHARPA-Project/kiara_plugin.language_processing]8;;\
#                                   documentation: ]8;id=325796;https://DHARPA-Project.github.io/kiara_plugin.language_processing/\https://DHARPA-Project.github.io/kiara_plugin.language_processing/]8;;\
#
#  Operation details
#                      Documentation   Create a list of stopwords from one or multiple sources.
#
#                                      This will download nltk stopwords if necessary, and merge all input lists into a single, sorted list
#                                      without duplicates.
#
#                      Inputs
#                                        field name   type   description                                      Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        languages    list   A list of languages, will be used to retrieve    no         -- no default --
#                                                            language-specific stopword from nltk.
#                                        stopwords    list   A list of additional, custom stopwords.          no         -- no default --
#
#
#                      Outputs
#                                        field name       type   description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        stopwords_list   list   A sorted list of unique stopwords.

# %%
import pandas as pd
custom_stopword_list = list(pd.read_csv('stop_words.csv')['stopword'])

# %%
inputs = {
    "languages": ["italian", "english"],
    "stopwords": custom_stopword_list
}

stopwords_outputs = kiara.run_job('create.stopwords_list', inputs=inputs)
my_stopwords_list = stopwords_outputs['stopwords_list']
my_stopwords_list.data
# Out:
# ListModel(list_data=['Indiana', 'Not', 'Which', 'Who', 'a', 'ab', 'abbastanza', 'abbia', 'abbiamo', 'abbiano', 'abbiate', 'about', 'above', 'ac', 'accidenti', 'ad', 'adesso', 'af', 'affinche', 'after', 'again', 'against', 'agl', 'agli', 'ahime', 'ahimã¨', 'ahimè', 'ai', 'ain', 'al', 'alcuna', 'alcuni', 'alcuno', 'ali', 'alio', 'all', 'alla', 'alle', 'allo', 'allora', 'altre', 'altri', 'altrimenti', 'altro', 'altrove', 'altrui', 'am', 'ami', 'an', 'anche', 'ancho', 'anco', 'ancora', 'and', 'ani', 'anni', 'anno', 'ano', 'ansa', 'anticipo', 'any', 'aono', 'ap', 'ar', 'are', 'aren', "aren't", 'as', 'assai', 'at', 'attesa', 'attraverso', 'au', 'avanti', 'avemmo', 'avendo', 'avente', 'aver', 'avere', 'averlo', 'avesse', 'avessero', 'avessi', 'avessimo', 'aveste', 'avesti', 'avete', 'aveva', 'avevamo', 'avevano', 'avevate', 'avevi', 'avevo', 'avrai', 'avranno', 'avrebbe', 'avrebbero', 'avrei', 'avremmo', 'avremo', 'avreste', 'avresti', 'avrete', 'avrà', 'avrò', 'avuta', 'avute', 'avuti', 'avuto', 'b', 'ba', 'basta', 'be', 'because', 'been', 'before', 'being', 'below', 'ben', 'bene', 'benissimo', 'berlusconi', 'between', 'both', 'box', 'brava', 'bravo', 'buono', 'but', 'by', 'c', 'ca', 'cai', 'can', 'casa', 'caso', 'cav', 'cento', 'certa', 'certe', 'certi', 'certo', 'che', 'chi', 'chicchessia', 'chiunque', 'cho', 'ci', 'ciascuna', 'ciascuno', 'cima', 'cinque', 'cio', 'cioe', 'cioã¨', 'cioè', 'circa', 'citta', 'città', 'cittã', 'ciã²', 'ciò', 'cl', 'clic', 'co', 'codesta', 'codesti', 'codesto', 'cogli', 'coi', 'col', 'colei', 'coll', 'coloro', 'colui', 'com', 'come', 'cominci', 'comprare', 'comunque', 'con', 'concernente', 'conciliarsi', 'conclusione', 'coni', 'consecutivi', 'consecutivo', 'consiglio', 'contro', 'cortesia', 'cos', 'cosa', 'cosi', 'cosã¬', 'così', 'cou', 'couldn', "couldn't", 'county', 'cui', 'd', 'da', 'dagl', 'dagli', 'dai', 'daily', 'dal', 'dall', 'dalla', 'dalle', 'dallo', 'dappertutto', 'davanti', 'degl', 'degli', 'dei', 'del', 'dell', 'della', 'delle', 'dello', 'dentro', 'detto', 'deve', 'devo', 'di', 'dice', 'did', 'didn', "didn't", 'die', 'dietro', 'dii', 'dire', 'dirimpetto', 'diventa', 'diventare', 'diventato', 'dl', 'do', 'does', 'doesn', "doesn't", 'dogli', 'doi', 'doing', 'dol', 'dolio', 'dolla', 'don', "don't", 'dopo', 'doppio', 'dov', 'dove', 'dovo', 'dovra', 'dovrà', 'dovrã', 'dovunque', 'down', 'due', 'dunque', 'duo', 'durante', 'during', 'e', 'each', 'ebbe', 'ebbero', 'ebbi', 'ecc', 'ecco', 'ed', 'effettivamente', 'egli', 'ehe', 'eli', 'elio', 'ella', 'elle', 'entrambi', 'eon', 'eppure', 'era', 'erano', 'eravamo', 'eravate', 'eri', 'ero', 'es', 'esempio', 'esse', 'essendo', 'esser', 'essere', 'essi', 'ex', 'f', 'fa', 'faccia', 'facciamo', 'facciano', 'facciate', 'faccio', 'facemmo', 'facendo', 'facesse', 'facessero', 'facessi', 'facessimo', 'faceste', 'facesti', 'faceva', 'facevamo', 'facevano', 'facevate', 'facevi', 'facevo', 'fai', 'fanno', 'farai', 'faranno', 'fare', 'farebbe', 'farebbero', 'farei', 'faremmo', 'faremo', 'fareste', 'faresti', 'farete', 'farà', 'farò', 'fatto', 'favore', 'fe', 'fece', 'fecero', 'feci', 'few', 'fi', 'fin', 'finalmente', 'finche', 'fine', 'fino', 'for', 'forse', 'forza', 'fosse', 'fossero', 'fossi', 'fossimo', 'foste', 'fosti', 'fra', 'francisco.cal', 'frattempo', 'from', 'ft', 'fu', 'fui', 'fummo', 'fuori', 'furono', 'further', 'futuro', 'g', 'ge', 'generale', 'gente', 'gi', 'gia', 'giacche', 'giorni', 'giorno', 'giu', 'già', 'giã', 'gl', 'gli', 'gliela', 'gliele', 'glieli', 'glielo', 'gliene', 'go', 'governo', 'grande', 'grazie', 'gruppo', 'h', 'ha', 'had', 'hadn', "hadn't", 'haha', 'hai', 'hanno', 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hers', 'herself', 'hi', 'him', 'himself', 'his', 'ho', 'how', 'i', 'ia', 'ie', 'iella', 'ielle', 'ieri', 'if', 'ih', 'ii', 'iii', 'il', 'ila', 'ile', 'ilei', 'ili', 'ilio', 'ilo', 'im', 'ima', 'imi', 'imo', 'improvviso', 'in', 'ina', 'inc', 'indietro', 'infatti', 'ing', 'ini', 'ino', 'inolt ...

# %%
inputs = {
    'tokens_array': outputs['tokens_array'],
    'remove_stopwords' : my_stopwords_list,
    'to_lowercase': True,
    'remove_non_alpha': True,
    'remove_short_tokens': 2
}

outputs = kiara.run_job('preprocess.tokens_array', inputs=inputs)
outputs
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────                               │
# │   tokens_array                                                                                                                           │
# │                    ['ragione', 'organo', 'difesa', 'vili', 'camorristi', 'sicari', 'falsari', 'aust ...                                  │
# │                    ['rag', 'vili', 'camorristi', 'sicari', 'falsari', 'austriacanti', 'nemici', 'pa ...                                  │
# │                    ['ragione', 'organo', 'difesa', 'italianità', 'vili', 'camorristi', 'sicari', 'f ...                                  │
# │                    ['vili', 'camorristi', 'sicari', 'falsari', 'austriacanti', 'nemici', 'patria',  ...                                  │
# │                    ['vili', 'camorristi', 'sicari', 'falsari', 'austriacanti', 'nemici', 'patria',  ...                                  │
# │                    ['ragiona', 'organo', 'difesa', 'italianità', 'vili', 'camorristi', 'sicari', 'f ...                                  │
# │                    ['ragione', 'organo', 'difesa', 'vili', 'camorristi', 'sicari', 'falsari', 'aust ...                                  │
# │                    ['ragione', 'vili', 'camorristi', 'sicari', 'falsari', 'austriacanti', 'nemici', ...                                  │
# │                    ['vili', 'camorristi', 'sicari', 'falsari', 'austriacanti', 'nemici', 'patria',  ...                                  │
# │                    ['rag', 'organo', 'difesa', 'italianità', 'vili', 'camorristi', 'sicari', 'falsa ...                                  │
# │                    ['vili', 'camorristi', 'sicari', 'falsari', 'austriacanti', 'nemici', 'patria',  ...                                  │
# │                    ['rassegna', 'phones', 'rassegna', 'colonia', 'risentita', 'necessità', 'giornal ...                                  │
# │                    ['rassegna', 'jjoth', 'phones', 'arte', 'amo', 'andati', 'assistendo', 'colo', ' ...                                  │
# │                    ['phones', 'quaiene', 'parie', 'uue', 'ama', 'maino', 'anelati', 'asaisienuo', ' ...                                  │
# │                    ['jsrìt', 'iik', 'phones', 'cose', 'ibi', 'dicendo', 'insinuando', 'colonia', 'g ...                                  │
# │                    ['phones', 'cose', 'dicendo', 'susurran', 'insinuando', 'colonia', 'gran', 'dose ...                                  │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
